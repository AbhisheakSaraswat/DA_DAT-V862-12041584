# %% [markdown]
# ### Python String:
#
# In Python, strings are immutable, which means we can not change the string after assignment.
# Python does not support char data type, so 1 single string is referred to as string with length of 1 char.
#
# Python provides varities of String function.
#
# Note: We can perform slicing on Python string, and String are indexable, In Python index starts from 0 to n - 1

# %% [markdown]
# ### All the functions from Python String:

# %%
# do not understand this line (focus on output only...)
print("All Functions from String: ",[i for i in dir(str) if "__" not in i])
# Out:
# All Functions from String:  ['capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
a = "U"

# %%
type(a)
# Out:
# str

# %%
len(a)
# Out:
# 1

# %%
a = ""

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# ''

# %%
a = "upGrad"

# %%
a
# Out:
# 'upGrad'

# %% [markdown]
# ### Note:
#
# In Python, Index always starts from 0 and ends with n - 1.

# %%
a[0]
# Out:
# 'u'

# %%
a[1]
# Out:
# 'p'

# %%
a[5]
# Out:
# 'd'

# %%
a[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a[6]
#
# IndexError: string index out of range

# %% [markdown]
# ### Note:
#
# In Python, Indexing can be positive or negative.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
st = "KNOWLEDGEHUT"

# %%
st[0]
# Out:
# 'K'

# %%
st[-1]
# Out:
# 'T'

# %%
st[1:5]
# Out:
# 'NOWL'

# %%
st[1:10:2]
# Out:
# 'NWEGH'

# %%
st
# Out:
# 'KNOWLEDGEHUT'

# %%
st[-5:-10]
# Out:
# ''

# %%
st
# Out:
# 'KNOWLEDGEHUT'

# %%
st[5:0]
# Out:
# ''

# %%
st[-5:-1]
# Out:
# 'GEHU'

# %%
st[-10:-5]
# Out:
# 'OWLED'

# %%
# IMMUATABLE

# %%
st
# Out:
# 'KNOWLEDGEHUT'

# %%
st[-1]
# Out:
# 'T'

# %%
st[-1] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 st[-1] = "A"
#
# TypeError: 'str' object does not support item assignment

# %%
string = "python is very EASY lanaGUAGe"

# %%
string
# Out:
# 'python is very EASY lanaGUAGe'

# %% [markdown]
# ### capitalize

# %%
print(string.capitalize.__doc__))
# Out:
# Return a capitalized version of the string.
#
# More specifically, make the first character have upper case and the rest lower
# case.

# %%
string.capitalize()
# Out:
# 'Python is very easy lanaguage'

# %% [markdown]
# ### Python Casefold function
#
# Using this function we can match our string as caseless.

# %%
"A" == "a"
# Out:
# False

# %%
st
# Out:
# 'KNOWLEDGEHUT'

# %%
st1 = "knowledgeHut"

# %%
st.casefold() == st1.casefold()
# Out:
# True

# %% [markdown]
# ### String Find or Index Function

# %%
quote = "Make it work, make it right, make it fast, make it now"

# %%
quote
# Out:
# 'Make it work, make it right, make it fast, make it now'

# %% [markdown]
# ### Find
#
# Using the find function we can find the index of any item in give string.
#
# Find function returns -1 in case of failure, which mean if any item is not the part of it then find function returns - 1.
#
# By default this function returns the lowest index of an item.

# %%
quote.find("work")
# Out:
# 8

# %%
quote.find("Make")
# Out:
# 0

# %%
quote.find("make")
# Out:
# 14

# %%
quote
# Out:
# 'Make it work, make it right, make it fast, make it now'

# %%
quote.find("Modi")
# Out:
# -1

# %%
quote.find("it")
# Out:
# 5

# %%
quote
# Out:
# 'Make it work, make it right, make it fast, make it now'

# %%
quote.find("it", 5 + 1)
# Out:
# 19

# %%
quote.find("it", quote.find("it") + 1)
# Out:
# 19

# %%
quote.find("it", quote.find("it", quote.find("it") + 1) + 1)
# Out:
# 34

# %%
quote.find("it", quote.find("it", quote.find("it", quote.find("it") + 1) + 1) + 1)
# Out:
# 48

# %% [markdown]
# ### Index
#
# Find and Index both are same, where Find returns - 1 in case of failure, where as Index function raise an error when it is failure.

# %%
quote.find("Modi")
# Out:
# -1

# %%
quote.index("Modi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 quote.index("Modi")
#
# ValueError: substring not found

# %%
quote.index("it", quote.index("it", quote.index("it") + 1) + 1)
# Out:
# 34

# %%
quote
# Out:
# 'Make it work, make it right, make it fast, make it now'

# %%
quote.index("it")
# Out:
# 5

# %% [markdown]
# ### rfind and rindex
#
# Search the data from the right side but counting the index from the left side

# %%
quote.rfind("it")
# Out:
# 48

# %%
quote.rindex('it')
# Out:
# 48

# %%
quote.rfind("Modi")
# Out:
# -1

# %%
quote.rindex("Modi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 quote.rindex("Modi")
#
# ValueError: substring not found

# %% [markdown]
# ### very good query by Mr. Karan, but please explore by yourself.

# %% [markdown]
# * Split
# * rSplit
# * Partition
# * rPartition

# %%
print("We are learning Python with Abhisheak!!!")

print("We are learning Python with Abhisheak!!!")

print("We are learning Python with Abhisheak!!!")
# Out:
# We are learning Python with Abhisheak!!!
# We are learning Python with Abhisheak!!!
# We are learning Python with Abhisheak!!!

# %%
bucket = "Veg,Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk"

# %%
bucket
# Out:
# 'Veg,Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk'

# %% [markdown]
# ### Split Function
#
# Using this function we can split the data based on any specified char and it wil return an <b> output in the form of list data structure,</b> if you are not passing anything to split the data then this function <b> by default try to split the data based on white space</b>.
#
# Note: Split function split the data from left to right.

# %%
name = "Ankit Kumar Sharma"

# %%
name.split()
# Out:
# ['Ankit', 'Kumar', 'Sharma']

# %%
name.split("a")

# Ankit Kum, r Sh,rm,''
# Out:
# ['Ankit Kum', 'r Sh', 'rm', '']

# %%
bucket
# Out:
# 'Veg,Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk'

# %%
bucket.split(",")
# Out:
# ['Veg', 'Bread', 'Egg', 'Chocolate', 'Fruit', 'Paneer', 'Soya', 'Milk']

# %%
bucket.split(",",3)
# Out:
# ['Veg', 'Bread', 'Egg', 'Chocolate,Fruit,Paneer,Soya,Milk']

# %%
bucket.split(",",1)
# Out:
# ['Veg', 'Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk']

# %%
bucket.split(",",5)
# Out:
# ['Veg', 'Bread', 'Egg', 'Chocolate', 'Fruit', 'Paneer,Soya,Milk']

# %%
name
# Out:
# 'Ankit Kumar Sharma'

# %%
name.split(" ",1)
# Out:
# ['Ankit', 'Kumar Sharma']

# %%
email = "myprogrammingisfun@gmail.com"

# %%
email.split("@")
# Out:
# ['myprogrammingisfun', 'gmail.com']

# %%
print("User Name: ",email.split("@")[0])
# Out:
# User Name:  myprogrammingisfun

# %%
print("Domain Name: ",email.split("@")[-1])
# Out:
# Domain Name:  gmail.com

# %%
lst = ["A","B","C","D"]

# %%
lst[0]
# Out:
# 'A'

# %%
lst[-1]
# Out:
# 'D'

# %%
lst[-4]
# Out:
# 'A'

# %%
lst[-1]
# Out:
# 'D'

# %%
email = "sugandha.arora@xyz.com"

# %%
email.split("@")[0]
# Out:
# 'sugandha.arora'

# %%
email.split("@")[-2]
# Out:
# 'sugandha.arora'

# %%
email.split("@")[1]
# Out:
# 'xyz.com'

# %%
email.split("@")[-1]
# Out:
# 'xyz.com'

# %%
email.split("@")[-2].split(".")
# Out:
# ['sugandha', 'arora']

# %% [markdown]
# ### rsplit

# %%
bucket
# Out:
# 'Veg,Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk'

# %%
name
# Out:
# 'Ankit Kumar Sharma'

# %%
name.rsplit()
# Out:
# ['Ankit', 'Kumar', 'Sharma']

# %%
name.split()
# Out:
# ['Ankit', 'Kumar', 'Sharma']

# %%
name.split(" ",1)
# Out:
# ['Ankit', 'Kumar Sharma']

# %%
name.rsplit(" ",1)
# Out:
# ['Ankit Kumar', 'Sharma']

# %%
bucket
# Out:
# 'Veg,Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk'

# %%
bucket.rsplit(",",3)
# Out:
# ['Veg,Bread,Egg,Chocolate,Fruit', 'Paneer', 'Soya', 'Milk']

# %% [markdown]
# ### Partition and rPartition
#
# Using Partition function we can partition the data based on specified char, this function always return an outputs in the form of Tuple Data Strucutre (that is represented by ()), and that tuple at least or at most contain only 3 item.
#
# Note: If any specified char is not the part of your data then this function
# also return an output with 3 items in the form of tuple.
#
#
# Note: Partition the data based on first occurence.

# %%
print(name.partition.__doc__)
# Out:
# Partition the string into three parts using the given separator.
#
# This will search for the separator in the string.  If the separator is found,
# returns a 3-tuple containing the part before the separator, the separator
# itself, and the part after it.
#
# If the separator is not found, returns a 3-tuple containing the original string
# and two empty strings.

# %%
name
# Out:
# 'Ankit Kumar Sharma'

# %%
name.partition(" ")
# Out:
# ('Ankit', ' ', 'Kumar Sharma')

# %%
["A","B","C"] # list -> long bracket
# Out:
# ['A', 'B', 'C']

# %%
("A","B","C") # tuple -> Parenthesis
# Out:
# ('A', 'B', 'C')

# %%
name
# Out:
# 'Ankit Kumar Sharma'

# %%
name.partition("|")
# Out:
# ('Ankit Kumar Sharma', '', '')

# %%
bucket
# Out:
# 'Veg,Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk'

# %%
bucket.partition(",")
# Out:
# ('Veg', ',', 'Bread,Egg,Chocolate,Fruit,Paneer,Soya,Milk')

# %%
name
# Out:
# 'Ankit Kumar Sharma'

# %%
name.partition("a")
# Out:
# ('Ankit Kum', 'a', 'r Sharma')

# %%
name.rpartition("a")
# Out:
# ('Ankit Kumar Sharm', 'a', '')

# %%
name = "Sugandha-arora"

# %%
name.rpartition("--")
# Out:
# ('Sugandha', '-', 'arora')

# %%
name.rpartition("n")
# Out:
# ('Suga', 'n', 'dha-arora')

# %%
a = 5

# %%
5 * "*"
# Out:
# '*****'

# %%
email = "kual.kumar12@gmail.com"

# %%
k**********2@g****.com

# %% [markdown]
# ### Home Task

# %%
# email = "abcd@gmail.com"
# a**d@g****.com

# abhishek.s@yahoo.co.in

# a********s@y*******.in

# First char and last char from your username and in between all char should be *
# from domain name, I want first char and everything after last dot, in between all should be *

# %%
email = input("Enter your email: ")
# here your logic
print(email)
# Out:
# Enter your email: abc@gmail.com
# abc@gmail.com

# %%
a = "abhi"
b = "sheK"
a + b
# Out:
# 'abhisheK'

# %%
name
# Out:
# 'Sugandha-arora'

# %% [markdown]
# ### lower, upper, swapcase

# %%
name.lower()
# Out:
# 'sugandha-arora'

# %%
name.upper()
# Out:
# 'SUGANDHA-ARORA'

# %%
name.swapcase()
# Out:
# 'sUGANDHA-ARORA'

# %% [markdown]
# ### Join
#
# Using this function we can join string, list, tuple etc

# %%
name
# Out:
# 'Sugandha-arora'

# %%
"|".join(name)
# Out:
# 'S|u|g|a|n|d|h|a|-|a|r|o|r|a'

# %%
lst
# Out:
# ['A', 'B', 'C', 'D']

# %%
"&".join(lst)
# Out:
# 'A&B&C&D'

# %% [markdown]
# ### strip, lstrip, rstrip
#
# Using these we can remove specified chars from left side or right side, or both side.
#
# * strip: removing leading and trailing char from both side
# * rstrip: from right side
# * lstrip: from left side
#
# By default based on space it will remove.

# %%
name = "  Abhisheak Saraswat   ***"

# %%
name
# Out:
# '  Abhisheak Saraswat   ***'

# %%
name.lstrip()
# Out:
# 'Abhisheak Saraswat   ***'

# %%
name.lstrip(" A")
# Out:
# 'bhisheak Saraswat   ***'

# %%
name.rstrip("* ")
# Out:
# '  Abhisheak Saraswat'

# %%
name.rstrip("* ").lstrip()
# Out:
# 'Abhisheak Saraswat'

# %%
name = "******Abhishek Saraswat****"

# %%
name.lstrip("*")
# Out:
# 'Abhishek Saraswat****'

# %%
name.rstrip("*")
# Out:
# '******Abhishek Saraswat'

# %%
name.strip("*")
# Out:
# 'Abhishek Saraswat'

# %% [markdown]
# ###  Startswith and EndsWith

# %%
quote
# Out:
# 'Make it work, make it right, make it fast, make it now'

# %%
quote.startswith("Make")
# Out:
# True

# %%
quote.endswith("now")
# Out:
# True

# %%
quote.endswith("Abhishek")
# Out:
# False

# %%
quote.endswith("Modi")
# Out:
# False

# %%
quote.endswith("w")
# Out:
# True

# %%
name = "abhishe2342@#$"

# %%
name.isdigit()
# Out:
# False

# %%
name.isnumeric()
# Out:
# False

# %%
name.isalnum()
# Out:
# False

# %%
name = "abhishe234"

# %% [markdown]
# ### isalnum:
#
# if your string contains either alpha or number then this function return an output as True

# %%
name.isalnum()
# Out:
# True

# %%
name = "Abhishek"

# %%
name.isalnum()
# Out:
# True

# %%
name = "02849243"

# %%
name.isnumeric()
# Out:
# True

# %%
name = "Abhishek"

# %%
name.isalpha()
# Out:
# True

# %%
name = "abhishek123"
name.isalpha()
# Out:
# False

# %%
name.isalnum()
# Out:
# True

# %%
name = "23589adsjfsa#$"

# %%
name.isalnum()
# Out:
# False

# %%
name = "12.45"

# %%
name.isdecimal?

# %%
name = 'H.12'

# %%
name.isdecimal()
# Out:
# False

# %%
number = "100.00"

# %%
number.isdecimal()
# Out:
# False

# %%
"100".isdecimal()
# Out:
# True

# %%
number = "100."

# %%
number.isdecimal()
# Out:
# False

# %%
a = "100"

# %%
a.isnumeric()
# Out:
# True
