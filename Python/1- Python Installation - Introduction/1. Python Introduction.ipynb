# %% [markdown]
# ### How to check Python Installation:
# 1. Open Your CMD
# 2. Just type 'where python'

# %% [markdown]
# ### Python Introduction:
#
# Python is very popular and general purpose programming language.
#
# This programming language is very popular for below task:
#
# * Software Development
# * Data Analytics
# * Data Science
# * Machine learning
# * Generative AI or AI
# * IOTs
# * Web Development
# * GUI Development
# * Game Development
# * Scientific Computing
# * App Development (not Recommended)
# * Software Testing
# * Robotics
# * Web Scrapping
# * etc

# %% [markdown]
# ### Note:
#
# Python is general purpose and case-sensitive programming language.

# %%
print("Hello Learners!!!")
# Out:
# Hello Learners!!!

# %%
print("Manya")
# Out:
# Manya

# %%
print("upGrad")
# Out:
# upGrad

# %%
print("upGrad")
print("KnowledgeHut")
# Out:
# upGrad
# KnowledgeHut

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("upGrad", end = "\n") # next line
print("KnowledgeHut")
# Out:
# upGrad
# KnowledgeHut

# %%
print("upGrad", end = "-")
print("KnowledgeHut")
# Out:
# upGrad-KnowledgeHut

# %%
print("upGrad", end = " ")
print("KnowledgeHut")
# Out:
# upGrad KnowledgeHut

# %% [markdown]
# ### Python is case-sensitive programming language.

# %%
"aman" == "Aman"
# Out:
# False

# %%
'aman' == "aman"
# Out:
# True

# %%
"A" == "a"
# Out:
# False

# %%
"A" == 'A'
# Out:
# True

# %%
# using single hash, we can write a single line of comment in Python

# %%
A = 10

# %%
print(A)
# Out:
# 10

# %% [markdown]
# ## Note:
#
# In JupyterNotebook, Your function or numbers always in green color.

# %% [markdown]
# ### Python Keyword

# %%
import keyword

# %%
# Any word in Jupyter notebook, found as a green bold -> keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("Total Count of keyword: ", len(keyword.kwlist))
# Out:
# Total Count of keyword:  35

# %% [markdown]
# ### Python Identifiers (Variable, Function, Class) :
#
# * Rules and guidelines of Identifiers
#     * An Identifiers can not starts with digit or special symbols
#     * An Identifier can starts with alpha or underscore in Python
#     * A Keyword can not be used as an Identifiers.
#     * We can defined Indetifier with alpha or digit or underscore

# %%
1a = 10
# Out:
#   Cell In[26], line 1
#     1a = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
or = 10
# Out:
#   Cell In[27], line 1
#     or = 10
#     ^
# SyntaxError: invalid syntax

# %%
and = 10
# Out:
#   Cell In[28], line 1
#     and = 10
#     ^
# SyntaxError: invalid syntax

# %%
raise = 10
# Out:
#   Cell In[29], line 1
#     raise = 10
#           ^
# SyntaxError: invalid syntax

# %%
# %a = 10
# Out:
# UsageError: Line magic function `%a` not found.

# %%
a = 10

# %%
_sum = 100

# %% [markdown]
# ### Note:
#
# Python supports <b> dynamic semantic</b> concept.
#
# Python understand the variable and its type based on the nature of the data.

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a = 32767
a
# Out:
# 32767

# %%
type(a)
# Out:
# int

# %%
a = 327699
type(a)
# Out:
# int

# %%
a
# Out:
# 327699

# %%
a = 948592384509284309528209840952845092384095238430952345902

# %%
type(a)
# Out:
# int

# %%
a
# Out:
# 948592384509284309528209840952845092384095238430952345902

# %%
a = 45092843095282098409528450923840952384.924850932485093289502384028509

# %%
type(a)
# Out:
# float

# %%
a
# Out:
# 4.5092843095282095e+37

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a = "Abhishek"

# %%
a
# Out:
# 'Abhishek'

# %%
type(a)
# Out:
# str

# %%
a = True

# %%
a
# Out:
# True

# %%
type(a)
# Out:
# bool

# %% [markdown]
# ### Next Agenda
#
# * Python Operators
# * Python F-String
# * Python String
# * Python Data Structure
#     * List
#     * Tuple
#     * Set
#     * Dict
#
# ____
#
# * Python Control Structure
# * Python Loop
#     * For Loop
#     * While Loop
# * Python File Handling
# * Python Excelption Handling
# * Python useful stuff.
